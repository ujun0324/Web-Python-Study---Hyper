# %% [markdown]
# <a href="https://colab.research.google.com/github/ujun0324/Web-Python-Study---Hyper/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Task 1 — New Product Arrives
#
# 현재 편의점 진열대에는 아래와 같은 간식이 있습니다.
#
# snacks = ["cola", "chips", "cola", "candy"]
#
# 👉 "chocolate"을 리스트 맨 뒤에 추가하세요.

# %%
snacks = ["cola", "chips", "cola", "candy"]

snacks.append("chocolate")

print(snacks)
# Out:
# ['cola', 'chips', 'cola', 'candy', 'chocolate']

# %% [markdown]
# ## Task 2 — Cola Stock
#
# 현재 편의점 진열대에는 아래와 같은 간식이 있습니다.
#
# snacks = ["cola", "chips", "cola", "candy"]
#
# 👉 리스트에서 "cola"가 몇 개 있는지 출력하세요.

# %%
snacks = ["cola", "chips", "cola", "candy"]

print(snacks.count("cola"))
# Out:
# 2

# %% [markdown]
# ## Task 3 — Find Chips
#
# 현재 편의점 진열대에는 아래와 같은 간식이 있습니다.
#
# snacks = ["cola", "chips", "cola", "candy"]
#
# 👉 "chips"가 리스트에서 몇 번째 위치에 있는지 출력하세요.

# %%
snacks = ["cola", "chips", "cola", "candy"]

print(snacks.index("chips"))
# Out:
# 1

# %% [markdown]
# ## Task 4 — Remove Expired Snack
#
# 현재 편의점 진열대에는 아래와 같은 간식이 있습니다.
#
# snacks = ["cola", "chips", "cola", "candy"]
#
# 👉 "candy"를 리스트에서 삭제하세요.

# %%
snacks = ["cola", "chips", "cola", "candy"]

snacks.remove("candy")

print(snacks)
# Out:
# ['cola', 'chips', 'cola']

# %% [markdown]
# ## Task 5 — New Shelf
#
# 현재 편의점 진열대에는 아래와 같은 간식이 있습니다.
#
# snacks = ["cola", "chips", "cola", "candy"]
#
# 새로운 간식이 들어왔습니다.
#
# new_snacks = ["jelly", "cookie"]
#
# 👉 기존 리스트와 새로운 리스트를 병합하세요.

# %%
snacks = ["cola", "chips", "cola", "candy"]
new_snacks = ["jelly", "cookie"]

snacks.extend(new_snacks)

print(snacks)
# Out:
# ['cola', 'chips', 'cola', 'candy', 'jelly', 'cookie']

# %%
import base64

class HYPER_Grader:
    def __init__(self):
        self.answers = {
            1: "WzMsIDQsIDVd",        # [3, 4, 5]
            2: "MjU=",                # 25
            3: "Sm9obg==",            # John
            4: "Mw==",                # 3
            5: "VHJ1ZQ=="             # True
        }

    def check(self, task_id, user_answer):
        try:
            expected = base64.b64decode(self.answers[task_id]).decode()
            result = str(user_answer).strip()
            expected = expected.strip()

            if result == expected:
                print(f"Task {task_id}: ✅ 정답입니다!")
            else:
                print(f"Task {task_id}: ❌ 틀렸습니다.")
                print("당신의 출력:", result)
                print("정답:", expected)

        except Exception as e:
            print(f"Task {task_id}: ⚠ 에러 발생 ({e})")

grader = HYPER_Grader()
print("채점 준비 완료!")
# Out:
# 채점 준비 완료!

# %% [markdown]
# # HYPER PYTHON STUDY — WEEK 2 APPLICATION PROBLEMS
#
# 이번 문제들은 단순 문법이 아니라
# **Python 자료형을 활용한 응용 문제**입니다.
#
# 사용되는 자료형
#
# - List
# - Tuple
# - Dictionary
# - Set
# - Boolean
#
# 각 문제에서 **answer 변수에 결과를 저장하세요.**

# %% [markdown]
# ## Task 1 — Recent Scores
#
# 다음은 학생의 시험 점수 기록입니다.
#
# scores = [1, 2, 3, 4, 5]
#
# 👉 **최근 시험 3개 점수만** 리스트로 만들어
# answer 변수에 저장하세요.

# %%
scores = [1, 2, 3, 4, 5]

answer = None

answer = scores[2:]


grader.check(1, answer)
# Out:
# Task 1: ✅ 정답입니다!

# %% [markdown]
# ## Task 2 — Price Calculation
#
# 다음 튜플은 상품 정보입니다.
#
# product = ("coffee", 5)
#
# 튜플 구조
#
# (name, price)
#
# 👉 price를 꺼내서 **5개를 샀을 때 총 가격**을
# answer 변수에 저장하세요.

# %%
product = ("coffee", 5)

answer = None

answer = product[1] * 5


grader.check(2, answer)
# Out:
# Task 2: ✅ 정답입니다!

# %% [markdown]
# ## Task 3 — Student Database
#
# 다음은 학생 정보입니다.
#
# student = {
#     "id": 101,
#     "name": "John",
#     "age": 20
# }
#
# 👉 학생 이름(name)을 조회하여
# answer 변수에 저장하세요.

# %%
student = {
    "id": 101,
    "name": "John",
    "age": 20
}

answer = None

answer = student["name"]


grader.check(3, answer)
# Out:
# Task 3: ✅ 정답입니다!

# %% [markdown]
# ## Task 4 — Unique Visitors
#
# 웹사이트 방문 기록입니다.
#
# visitors = ["Tom", "John", "Tom", "Alice", "John"]
#
# 👉 중복을 제거한 **방문자 수**를
# answer 변수에 저장하세요.

# %%
visitors = ["Tom", "John", "Tom", "Alice", "John"]

answer = None

answer = len(set(visitors))


grader.check(4, answer)
# Out:
# Task 4: ✅ 정답입니다!

# %% [markdown]
# ## Task 5 — Access Control
#
# 관리자 목록입니다.
#
# admins = ["Alice", "Bob", "Charlie"]
#
# 사용자 이름이 아래와 같습니다.
#
# user = "Alice"
#
# 👉 user가 관리자 목록에 있는지 확인하고
# 결과(True / False)를 answer 변수에 저장하세요.

# %%
admins = ["Alice", "Bob", "Charlie"]
user = "Alice"

answer = None

answer = (user in admins)


grader.check(5, answer)
# Out:
# Task 5: ✅ 정답입니다!
